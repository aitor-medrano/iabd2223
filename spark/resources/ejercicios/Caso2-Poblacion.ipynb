# %%
# A partir del fichero de clientes, para cada ciudad, calcular cuantos clientes tenemos

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate() 
sc = spark.sparkContext
# Out:
# 22/03/07 20:01:42 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
clientesRDD = sc.textFile("customer.txt")

# %%
# Utilizamos map para generar tuplas (ciudad, 1) - La ciudad es el 6ª elemento del CSV

# %%
ciudadesRDD = clientesRDD.map(lambda x: (x.split(",")[6], 1))

# %%
ciudadesRDD.collect()
# Out:
# [('Brownsville', 1),
#  ('Littleton', 1),
#  ('Caguas', 1),
#  ('San Marcos', 1),
#  ('Caguas', 1),
#  ('Passaic', 1),
#  ('Caguas', 1),
#  ('Lawrence', 1),
#  ('Caguas', 1),
#  ('Stafford', 1),
#  ('Caguas', 1),
#  ('San Antonio', 1),
#  ('Caguas', 1),
#  ('Pico Rivera', 1),
#  ('Fontana', 1),
#  ('Caguas', 1),
#  ('Taylor', 1),
#  ('Martinez', 1),
#  ('Caguas', 1),
#  ('West New York', 1),
#  ('Caguas', 1),
#  ('North Bergen', 1),
#  ('San Juan', 1),
#  ('Caguas', 1),
#  ('Peoria', 1),
#  ('Glenview', 1),
#  ('Caguas', 1),
#  ('Longview', 1),
#  ('Fort Worth', 1),
#  ('Caguas', 1),
#  ('Albuquerque', 1),
#  ('Caguas', 1),
#  ('Norfolk', 1),
#  ('Caguas', 1),
#  ('Oceanside', 1),
#  ('Caguas', 1),
#  ('Norfolk', 1),
#  ('Opelousas', 1),
#  ('Caguas', 1),
#  ('Long Beach', 1),
#  ('Brooklyn', 1),
#  ('Duluth', 1),
#  ('Caguas', 1),
#  ('Napa', 1),
#  ('Denver', 1),
#  ('Freeport', 1),
#  ('Caguas', 1),
#  ('Strongsville', 1),
#  ('Caguas', 1),
#  ('San Bernardino', 1),
# ...

# %%
reducidoRDD = ciudadesRDD.reduceByKey(lambda a,b: a+b)
reducidoRDD.collect()
# Out:
# [('Littleton', 3),
#  ('San Marcos', 8),
#  ('Fontana', 4),
#  ('Martinez', 2),
#  ('West New York', 4),
#  ('Peoria', 5),
#  ('Glenview', 4),
#  ('Longview', 2),
#  ('Fort Worth', 8),
#  ('Norfolk', 4),
#  ('Oceanside', 3),
#  ('Brooklyn', 47),
#  ('Napa', 3),
#  ('Freeport', 4),
#  ('Chicago', 62),
#  ('Roswell', 6),
#  ('Princeton', 3),
#  ('Los Angeles', 59),
#  ('Philadelphia', 24),
#  ('Jacksonville', 8),
#  ('Knoxville', 2),
#  ('Ithaca', 2),
#  ('Atlanta', 11),
#  ('Spring', 3),
#  ('Annapolis', 2),
#  ('Hyattsville', 5),
#  ('Saint Paul', 15),
#  ('Beaverton', 3),
#  ('West Covina', 5),
#  ('Cincinnati', 2),
#  ('Oxnard', 7),
#  ('Amarillo', 8),
#  ('Augusta', 3),
#  ('San Diego', 23),
#  ('Dayton', 2),
#  ('Union', 2),
#  ('Florissant', 7),
#  ('Columbus', 11),
#  ('Chino', 3),
#  ('Dundalk', 1),
#  ('Hayward', 6),
#  ('Lindenhurst', 3),
#  ('Lancaster', 14),
#  ('Pompano Beach', 9),
#  ('Bayamon', 5),
#  ('Salinas', 5),
#  ('Carol Stream', 2),
#  ('Wheeling', 1),
# ...

# %%
# formateamos la salida a ciudad,cantidad
formateadoRDD = reducidoRDD.map(lambda x: str(x[0]) + "," + str(x[1]))

# %%
formateadoRDD.saveAsTextFile("poblacionCiudades")
